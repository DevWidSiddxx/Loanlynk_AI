# %%
import cv2
import pytesseract
import google.generativeai as genai
from PIL import Image
import os

# Configure Google Gemini API (Replace with your actual API key)
genai.configure(api_key="AIzaSyC4xW10yQNqgOfkbkc5iPe5GYsyiOreUWQ")

def extract_text_from_image(image_path):
    """Extract text from an image using Google Gemini API."""
    try:
        with open(image_path, "rb") as img_file:
            image_data = img_file.read()

        model = genai.GenerativeModel('gemini-pro-vision')
        response = model.generate_content([image_data])

        extracted_text = response.text if response else ""
        return extracted_text

    except Exception as e:
        print(f"Error extracting text: {e}")
        return ""

def parse_payslip_data(text):
    """Extract key details from the text using keyword matching."""
    payslip_data = {}

    # Extract details
    lines = text.split("\n")
    for line in lines:
        if "Employee name" in line:
            payslip_data["Employee Name"] = line.split(":")[-1].strip()
        elif "Date of Joining" in line:
            payslip_data["Date of Joining"] = line.split(":")[-1].strip()
        elif "Total Earnings" in line:
            payslip_data["Total Earnings"] = line.split()[-1].strip()
        elif "Net Pay" in line:
            payslip_data["Net Pay"] = line.split()[-1].strip()
        elif "Deductions" in line:
            payslip_data["Total Deductions"] = line.split()[-1].strip()

    return payslip_data

# Upload the payslip image
image_path = "/content/payslippp.png"  # Replace with the actual image path

# Extract text from the image using Gemini API
extracted_text = extract_text_from_image(image_path)

# If Gemini API fails, use Tesseract OCR as a fallback
if not extracted_text.strip():
    extracted_text = pytesseract.image_to_string(Image.open(image_path))

# Parse the extracted text
payslip_info = parse_payslip_data(extracted_text)

# Display the extracted details
print("\n🔹 Extracted Payslip Details 🔹")
for key, value in payslip_info.items():
    print(f"{key}: {value}")
# Out:
# Error extracting text: Could not create `Blob`, expected `Blob`, `dict` or an `Image` type(`PIL.Image.Image` or `IPython.display.Image`).
# Got a: <class 'bytes'>
# ...
